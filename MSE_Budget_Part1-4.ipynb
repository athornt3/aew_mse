# %% [markdown]
# # Calculate the terms of the MSE budget
#
# This notebook follows the jas_mean notebook. It calculates each term of the MSE budget. Each term is vertically averaged after calculation
# - A. Aiyyer, Aug 2023
# - A. Thornton, Aug 2023

# %%
import numpy as np
import xarray as xr
import pandas as pd
from datetime import date
from numpy import absolute, exp, log

# Any import of metpy will activate the accessors
from metpy.units import units

#from metpy.calc import dewpoint_from_relative_humidity
from metpy.calc import first_derivative, geospatial_gradient, advection

import metpy.constants as constants

# %% [markdown]
# ### Path to data
# The '3d' directory contains everything we nee to calculate each advection term of the MSE budget. The 2d term folder can just be directly applied to the filter.

# %%
# regridded era5 4x daily data for variables

path_full = '/glade/scratch/athornton/era5_processed_data/3d/'

# %% [markdown]
# ### Select subset of dates

# %%
year_start  = 1998
month_start = 3
day_start   = 1

year_end  = 2022
month_end = 12
day_end   = 31


date_series = [pd.date_range(date(i,month_start,day_start),date(i,month_end,day_end), freq ='D') for i in range(year_start,year_end+1)]
# date_series is a list of lists. Lets unpack it now

dates_list = [element for sublist in date_series for element in sublist]
print(dates_list[0].strftime("%Y%m%d"))
print(dates_list[-1].strftime("%Y%m%d"))
# Out:
# 19980301
# 19980301

# %% [markdown]
# ### Mass-weighted vertical integral
# Same integral as the vert_integrate notebook

# %% [markdown]
# mass weighted vertical integral of a quantity
#
# \begin{align}
# [A] = \frac{1}{g}\int_{ps}^{pt} A dp
# \end{align}
#
# Which in practice is calculated as:
#
# \begin{align}
# [A] = \frac{1}{g} \sum_i \frac{(A[i+1] + A[i])}{2} (p[i]-p[i+1])
# \end{align}
#
# Assuming pressure levels go from top (lowest, eg 100 hPa) to bottom (highest, eg. 1000 hPa)

# %%
def mass_weighted_vert_integral(data):
    # data is expected to be on pressure levels
    levels = (data.level*units(data.level.units)).metpy.convert_units('Pa')
    deltaP = (levels - levels.shift(level=1)).metpy.convert_units('Pa')
    vert_int_data = ((data.shift(level=1)+data)*.5*deltaP).sum(dim='level') / constants.earth_gravity   
    return  vert_int_data

# %%
def print_minmax(var_str, data):
    print( var_str , ' min, max = ', data.min().values, data.max().values, data.metpy.units )
    return

# %%
# read the basic state MSE
varNam = 'mse'
variab = 'MSE'

# path to averages
path_bar = '/glade/scratch/athornton/era5_processed_data/jas_means/'+varNam+'_jas_1998_2022.nc'
ds = xr.open_dataset(path_bar)

# the basic state MSE [calculated using mse.ipynb]
hbar = ds[variab].metpy.convert_units('joule/kilogram')
print_minmax('hbar', hbar)

# read the basic state Zonal Wind
varNam = 'u'
variab = 'U'
# path to averages
path_bar = '/glade/scratch/athornton/era5_processed_data/jas_means/'+varNam+'_jas_1998_2022.nc'
ds = xr.open_dataset(path_bar)
# Extract variables
ubar = ds[variab]*units['meter / second']
print_minmax('ubar', ubar)


# read the basic state meridional Wind
varNam = 'v'
variab = 'V'
# path to averages
path_bar = '/glade/scratch/athornton/era5_processed_data/jas_means/'+varNam+'_jas_1998_2022.nc'
ds = xr.open_dataset(path_bar)
# Extract variables
vbar = ds[variab]*units['meter / second']
print_minmax('vbar', vbar)


# read the basic state meridional Wind
varNam = 'w'
variab = 'W'
# path to averages
path_bar = '/glade/scratch/athornton/era5_processed_data/jas_means/'+varNam+'_jas_1998_2022.nc'
ds = xr.open_dataset(path_bar)
# Extract variables
wbar = ds[variab]*units['pascal / second']
print_minmax('wbar', wbar)
# Out:
# hbar  min, max =  234208.42 372106.22 joule / kilogram
# ubar  min, max =  -29.158838 22.06894 meter / second
# vbar  min, max =  -11.439221 15.893557 meter / second
# wbar  min, max =  -0.72537154 1.002546 pascal / second

# %% [markdown]
# ### Advection terms to calculate:
#
# \begin{align}
# U:
# -\overline u \frac{\partial h'}{\partial x}
# -\ u' \frac{\partial \overline h}{\partial x}
# -\ u' \frac{\partial h'}{\partial x}
# \end{align}
# \begin{align}
# V:
# -\overline v \frac{\partial h'}{\partial y}
# -\ v' \frac{\partial \overline h}{\partial y}
# -\ v' \frac{\partial h'}{\partial y}
# \end{align}
# \begin{align}
# \omega:
# -\overline \omega \frac{\partial h'}{\partial p}
# -\omega' \frac{\partial \overline h}{\partial p}
# -\omega' \frac{\partial h'}{\partial p}
# \end{align}

# %%
for a_date in dates_list:
    print (a_date)
    # Term 1
    
    # get the 4x daily mse
    path_data = path_full + 'mse_' + a_date.strftime("%Y%m%d") + '.nc'
    ds = xr.open_dataset(path_data)
    h = ds.MSE.metpy.convert_units('joule/kilogram')
    
    # get the 4x daily zonal wind
    path_data = path_full + 'u_' + a_date.strftime("%Y%m%d") + '.nc'
    ds = xr.open_dataset(path_data)
    u = ds.U.metpy.quantify()
    
    
    # get the 4x daily zonal wind
    path_data = path_full + 'v_' + a_date.strftime("%Y%m%d") + '.nc'
    ds = xr.open_dataset(path_data)
    v = ds.V.metpy.quantify()
    
    
    # calculate the anomaly fields
    hp = h - hbar
    print_minmax('mse anomaly', hp)
   

    # calculate the anomaly fields
    up = u - ubar
    print_minmax('u anomaly', up)
   
    vp = v - vbar
    print_minmax('v anomaly', vp)
 
    # calculate the gradient of hp
    hp_dx, hp_dy = geospatial_gradient(hp)
    # Create  new xarray DataArrays with the calculated gradients
    hp_dx = xr.DataArray(hp_dx, coords=hp.coords, dims=hp.dims)
    hp_dy = xr.DataArray(hp_dy, coords=hp.coords, dims=hp.dims)

    # calculate the gradient of the mean MSE (hbar)
    hbar_dx, hbar_dy = geospatial_gradient(hbar)
    # Create new xarray DataArrays with the calculated gradients
    hbar_dx = xr.DataArray(hbar_dx, coords=hbar.coords, dims=hbar.dims)
    hbar_dy = xr.DataArray(hbar_dy, coords=hbar.coords, dims=hbar.dims)
  
    
    #----------------------------------------------------------------------------------------
    # terms = ubar dh'/dx  & vbar dh'/dy    
    # vertically integrated 
    path = '/glade/scratch/athornton/era5_processed_data/budget_terms/unfiltered_terms/'
    
    ubar_hp_dx_vint = mass_weighted_vert_integral(ubar*hp_dx).metpy.convert_units('watt/meter**2')
    ubar_hp_dx_vint.name = 'ubar_hp_dx_vint'
    file_out = path + 'ubar_hp_dx_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'
    ubar_hp_dx_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')
    
    vbar_hp_dy_vint = mass_weighted_vert_integral(vbar*hp_dy).metpy.convert_units('watt/meter**2')
    vbar_hp_dy_vint.name = 'vbar_hp_dy_vint'    
    file_out = path + 'vbar_hp_dy_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'
    vbar_hp_dy_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')
    
    print_minmax('ubar_hp_dx_vint', ubar_hp_dx_vint)

    
    #----------------------------------------------------------------------------------------
    # terms = u' d/dx (hbar) &    v' d/dy (hbar)
    

    up_hbar_dx_vint = mass_weighted_vert_integral(up*hbar_dx).metpy.convert_units('watt/meter**2')
    up_hbar_dx_vint.name = 'up_hbar_dx_vint'    
    file_out = path + 'up_hbar_dx_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    up_hbar_dx_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')

    vp_hbar_dy_vint = mass_weighted_vert_integral(vp*hbar_dy).metpy.convert_units('watt/meter**2')
    vp_hbar_dy_vint.name = 'vp_hbar_dy_vint'    
    file_out = path + 'vp_hbar_dy_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    vp_hbar_dy_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')
   
    print_minmax('up_hbar_dx_vint',up_hbar_dx_vint)

    
    #----------------------------------------------------------------------------------------
    # terms = u' dh'/dx    & v' dh'/dy    
    up_hp_dx_vint = mass_weighted_vert_integral(up*hp_dx).metpy.convert_units('watt/meter**2')
    up_hp_dx_vint.name = 'up_hp_dx_vint'    
    file_out = path + 'up_hp_dx_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    up_hp_dx_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')
    
    vp_hp_dy_vint = mass_weighted_vert_integral(vp*hp_dy).metpy.convert_units('watt/meter**2')
    vp_hp_dy_vint.name = 'vp_hp_dy_vint'    
    file_out = path + 'vp_hp_dy_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    vp_hp_dy_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')
    
    print_minmax('up_hp_dx_vint',up_hp_dx_vint)
  
    
    # now lets do the vertical advection terms
    
    # get the 4x daily vertical wind
    path_data = path_full + 'w_' + a_date.strftime("%Y%m%d") + '.nc'
    ds = xr.open_dataset(path_data)
    w = ds.W.metpy.quantify()
    print_minmax('w',w)

    wp = w - wbar
    print_minmax('wp',wp)
 
    wp_hp_dp_vint = mass_weighted_vert_integral( advection(hp, w=wp)).metpy.convert_units('watt/meter**2')
    wp_hp_dp_vint.name = 'wp_hp_dp_vint'    
    file_out = path + 'wp_hp_dp_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    wp_hp_dp_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')
    print_minmax('wp_hp_dp_vint',wp_hp_dp_vint)
  
    wbar_hp_dp_vint = mass_weighted_vert_integral( advection(hp, w=wbar)).metpy.convert_units('watt/meter**2')
    wbar_hp_dp_vint.name = 'wbar_hp_dp_vint'    
    file_out = path + 'wbar_hp_dp_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    wbar_hp_dp_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')    
    print_minmax('wbar_hp_dp_vint',wbar_hp_dp_vint)
  
    wp_hbar_dp_vint = mass_weighted_vert_integral( advection(hbar, w=wp)).metpy.convert_units('watt/meter**2')
    wp_hbar_dp_vint.name = 'wp_hbar_dp_vint'    
    file_out = path + 'wp_hbar_dp_vint' + '_unfiltered_' + a_date.strftime("%Y%m%d") + '.nc'    
    wp_hbar_dp_vint.metpy.dequantify().to_netcdf(path=file_out, format='NETCDF4', mode='w')    
    print_minmax('wp_hbar_dp_vint',wp_hbar_dp_vint)
# Out:
# 1998-03-01 00:00:00
# mse anomaly  min, max =  -53300.28 34729.594 joule / kilogram
# u anomaly  min, max =  -33.853237 80.5354 meter / second
# v anomaly  min, max =  -51.4111 44.526592 meter / second
# ubar_hp_dx_vint  min, max =  -1911.63509890789 2942.2751320262623 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2934.6129709737966 1272.8408606025278 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4084.813304181121 4582.618162287855 watt / meter ** 2
# w  min, max =  -9.337384 3.3871677 pascal / second
# wp  min, max =  -9.360845 3.3400865 pascal / second
# wp_hp_dp_vint  min, max =  -2414.3140021632616 15186.33681649854 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1165.3962314506089 916.8306443527352 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -18638.77668490677 3048.5384245176106 watt / meter ** 2
# 1998-03-02 00:00:00
# mse anomaly  min, max =  -54117.312 34216.406 joule / kilogram
# u anomaly  min, max =  -37.48516 82.5347 meter / second
# v anomaly  min, max =  -46.67174 48.55344 meter / second
# ubar_hp_dx_vint  min, max =  -2824.2078141868024 2257.2817089564046 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2580.6877741325834 1081.4268513488373 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3670.1134057687937 8982.558691618793 watt / meter ** 2
# w  min, max =  -8.320738 2.3476772 pascal / second
# wp  min, max =  -8.345227 2.6244512 pascal / second
# wp_hp_dp_vint  min, max =  -2985.009495773511 13197.14079152612 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1010.0740201605636 852.7427729941815 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -13208.388926100943 3436.226597117482 watt / meter ** 2
# 1998-03-03 00:00:00
# mse anomaly  min, max =  -56487.344 33595.03 joule / kilogram
# u anomaly  min, max =  -39.18318 83.19758 meter / second
# v anomaly  min, max =  -54.70144 48.65263 meter / second
# ubar_hp_dx_vint  min, max =  -3537.3682221149243 2375.022162296155 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2355.547093971465 858.9168043078324 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3235.9446659549603 11614.497296323072 watt / meter ** 2
# w  min, max =  -8.782783 2.747933 pascal / second
# wp  min, max =  -8.806897 2.7950377 pascal / second
# wp_hp_dp_vint  min, max =  -2231.8157387840083 12775.078428630777 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1279.499491378786 756.4479698036537 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -15490.573177891509 2389.560979598315 watt / meter ** 2
# 1998-03-04 00:00:00
# mse anomaly  min, max =  -55324.062 33939.03 joule / kilogram
# u anomaly  min, max =  -40.519054 84.51275 meter / second
# v anomaly  min, max =  -53.610424 45.044655 meter / second
# ubar_hp_dx_vint  min, max =  -2856.0254381029354 2612.192564543545 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2350.1788192611784 1067.8585511398105 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3100.1587784933467 10329.385247219427 watt / meter ** 2
# w  min, max =  -8.829399 2.6467187 pascal / second
# wp  min, max =  -8.863347 2.7765326 pascal / second
# wp_hp_dp_vint  min, max =  -2185.4350483758712 12877.648915169177 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -973.7870425075592 914.0008515971078 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -16319.6182513186 2565.129272389038 watt / meter ** 2
# 1998-03-05 00:00:00
# mse anomaly  min, max =  -56069.344 34179.47 joule / kilogram
# u anomaly  min, max =  -39.498596 84.943985 meter / second
# v anomaly  min, max =  -56.719997 51.799603 meter / second
# ubar_hp_dx_vint  min, max =  -3329.8464432284795 2213.0193779226906 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1987.7012061781365 1130.1293025798968 watt / meter ** 2
# up_hp_dx_vint  min, max =  -2895.207198792461 5219.568591339265 watt / meter ** 2
# w  min, max =  -12.273764 2.2985117 pascal / second
# wp  min, max =  -12.305681 2.3946187 pascal / second
# wp_hp_dp_vint  min, max =  -2038.4808028783632 16070.188841367088 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -775.5212878724303 717.1669930373745 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -18945.32552092046 2385.519154751712 watt / meter ** 2
# 1998-03-06 00:00:00
# mse anomaly  min, max =  -55951.562 34824.875 joule / kilogram
# u anomaly  min, max =  -32.832474 85.310814 meter / second
# v anomaly  min, max =  -60.1349 60.371746 meter / second
# ubar_hp_dx_vint  min, max =  -2568.8330224751217 2299.084195994802 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1491.57911796318 2028.2345105643444 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4795.973210932942 7253.814893456756 watt / meter ** 2
# w  min, max =  -12.750077 2.9396627 pascal / second
# wp  min, max =  -12.777976 2.9037077 pascal / second
# wp_hp_dp_vint  min, max =  -3252.320450414367 15477.889626035236 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -815.0354931329238 704.8551319746388 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -20301.857012526096 3004.08954852222 watt / meter ** 2
# 1998-03-07 00:00:00
# mse anomaly  min, max =  -53716.53 32447.0 joule / kilogram
# u anomaly  min, max =  -40.876945 78.85892 meter / second
# v anomaly  min, max =  -60.792217 60.552303 meter / second
# ubar_hp_dx_vint  min, max =  -3297.6992041572007 3271.543654915688 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2191.8155106345453 2241.7945989988707 watt / meter ** 2
# up_hp_dx_vint  min, max =  -5110.999955812586 6181.3210846945685 watt / meter ** 2
# w  min, max =  -11.262402 2.8347173 pascal / second
# wp  min, max =  -11.285283 2.8911564 pascal / second
# wp_hp_dp_vint  min, max =  -4941.017163716248 17503.712866861966 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1085.0486766526335 749.0461070897595 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -20899.035320755946 4137.502907774977 watt / meter ** 2
# 1998-03-08 00:00:00
# mse anomaly  min, max =  -55841.562 32967.22 joule / kilogram
# u anomaly  min, max =  -38.475624 84.94035 meter / second
# v anomaly  min, max =  -57.11281 55.963833 meter / second
# ubar_hp_dx_vint  min, max =  -3609.199731409375 2308.914709876144 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2445.112132257402 1535.6898572151413 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3629.5359000203075 9209.348439676804 watt / meter ** 2
# w  min, max =  -8.031088 3.749853 pascal / second
# wp  min, max =  -8.065007 3.6970139 pascal / second
# wp_hp_dp_vint  min, max =  -3703.1713291445144 10402.288755700733 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1257.5393210981879 678.3872589580565 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -12983.606091045738 3594.098285318785 watt / meter ** 2
# 1998-03-09 00:00:00
# mse anomaly  min, max =  -60320.312 32266.438 joule / kilogram
# u anomaly  min, max =  -41.592083 88.865234 meter / second
# v anomaly  min, max =  -52.889694 63.062244 meter / second
# ubar_hp_dx_vint  min, max =  -3981.7091363323702 1928.9045037494257 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1722.4236006973376 896.5765094421224 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4232.030584543798 13935.851089392258 watt / meter ** 2
# w  min, max =  -10.013102 2.5087047 pascal / second
# wp  min, max =  -10.036758 2.5158892 pascal / second
# wp_hp_dp_vint  min, max =  -3255.218434312037 13963.28053732759 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -844.1587051483625 714.678595198731 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -17777.055094880652 4082.3823139773876 watt / meter ** 2
# 1998-03-10 00:00:00
# mse anomaly  min, max =  -64938.688 33939.188 joule / kilogram
# u anomaly  min, max =  -40.48501 87.52974 meter / second
# v anomaly  min, max =  -54.195004 57.222446 meter / second
# ubar_hp_dx_vint  min, max =  -3077.090735327502 3787.39112872691 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2121.6749114393624 761.3703400383755 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4955.1013841401 11592.220623171426 watt / meter ** 2
# w  min, max =  -11.536507 2.134429 pascal / second
# wp  min, max =  -11.557738 2.305185 pascal / second
# wp_hp_dp_vint  min, max =  -2587.9023451785315 13249.229853689643 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -861.7182617864797 668.7665224573129 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -16506.476319429905 3221.428000885559 watt / meter ** 2
# 1998-03-11 00:00:00
# mse anomaly  min, max =  -63695.562 32866.406 joule / kilogram
# u anomaly  min, max =  -35.952812 89.53841 meter / second
# v anomaly  min, max =  -53.6858 51.77245 meter / second
# ubar_hp_dx_vint  min, max =  -3133.4852201655913 2571.8323015485857 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1398.9042483973114 987.3506181116358 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4706.757559665746 8286.922550833555 watt / meter ** 2
# w  min, max =  -6.66394 2.545866 pascal / second
# wp  min, max =  -6.696543 2.388312 pascal / second
# wp_hp_dp_vint  min, max =  -2789.962085702908 7046.407249170514 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1040.8427550384467 515.4941348787336 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -8519.889692638382 2414.201749749711 watt / meter ** 2
# 1998-03-12 00:00:00
# mse anomaly  min, max =  -66368.84 34330.5 joule / kilogram
# u anomaly  min, max =  -39.12236 84.51355 meter / second
# v anomaly  min, max =  -61.23806 43.616066 meter / second
# ubar_hp_dx_vint  min, max =  -2245.577237520454 1979.5987952896858 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1581.4587964360119 1600.1755192228063 watt / meter ** 2
# up_hp_dx_vint  min, max =  -7760.689941427853 13483.045755574323 watt / meter ** 2
# w  min, max =  -8.335845 2.8851118 pascal / second
# wp  min, max =  -8.362422 2.8361983 pascal / second
# wp_hp_dp_vint  min, max =  -2946.4878885187745 11174.538478025668 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -940.4856376769966 531.3985944891763 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -14114.306053337847 2249.447821158964 watt / meter ** 2
# 1998-03-13 00:00:00
# mse anomaly  min, max =  -60174.5 33323.594 joule / kilogram
# u anomaly  min, max =  -35.88281 90.30495 meter / second
# v anomaly  min, max =  -59.119644 48.17092 meter / second
# ubar_hp_dx_vint  min, max =  -2452.6968157853557 3329.6201425118848 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1504.2459575549683 870.745344774167 watt / meter ** 2
# up_hp_dx_vint  min, max =  -5988.441370866068 11823.73203427947 watt / meter ** 2
# w  min, max =  -9.180842 2.5318432 pascal / second
# wp  min, max =  -9.2103405 2.543299 pascal / second
# wp_hp_dp_vint  min, max =  -3040.4688895166 8629.32508798579 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -865.8657791253523 644.4952018051616 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -11176.124597732545 2855.456436837932 watt / meter ** 2
# 1998-03-14 00:00:00
# mse anomaly  min, max =  -55779.125 33451.156 joule / kilogram
# u anomaly  min, max =  -30.64827 95.15767 meter / second
# v anomaly  min, max =  -65.28649 53.308235 meter / second
# ubar_hp_dx_vint  min, max =  -4491.31510999268 4638.149854654758 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1645.3920453200913 1546.648866971785 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4879.646993536473 7446.350721824017 watt / meter ** 2
# w  min, max =  -9.043607 2.2056286 pascal / second
# wp  min, max =  -9.070653 2.1709054 pascal / second
# wp_hp_dp_vint  min, max =  -3850.855986999975 11919.110290778468 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -967.2537294317069 589.7633572024664 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -13306.119976104903 4256.900748933368 watt / meter ** 2
# 1998-03-15 00:00:00
# mse anomaly  min, max =  -49966.844 33416.22 joule / kilogram
# u anomaly  min, max =  -34.944786 84.090034 meter / second
# v anomaly  min, max =  -53.5657 42.699303 meter / second
# ubar_hp_dx_vint  min, max =  -3921.6018316783507 3454.3078482483425 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1869.668825662587 1692.1799718304362 watt / meter ** 2
# up_hp_dx_vint  min, max =  -2741.985764321882 3755.580483446535 watt / meter ** 2
# w  min, max =  -7.438964 3.177746 pascal / second
# wp  min, max =  -7.4640107 3.2304974 pascal / second
# wp_hp_dp_vint  min, max =  -3853.25822349788 9957.204142082297 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -957.7246703722159 490.6251289451117 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -11614.436704430538 2787.536528744982 watt / meter ** 2
# 1998-03-16 00:00:00
# mse anomaly  min, max =  -48466.875 32340.375 joule / kilogram
# u anomaly  min, max =  -37.539696 85.20598 meter / second
# v anomaly  min, max =  -46.947266 54.642746 meter / second
# ubar_hp_dx_vint  min, max =  -2540.4768240670633 2212.52027798991 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1518.5640177230823 1812.5676889259128 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3094.037659492433 11416.829110979905 watt / meter ** 2
# w  min, max =  -7.0635905 3.5283206 pascal / second
# wp  min, max =  -7.032988 3.4467294 pascal / second
# wp_hp_dp_vint  min, max =  -6111.265916814317 9911.479802577716 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -992.4106071588777 512.3830607039577 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -12434.743283357908 4159.055322967645 watt / meter ** 2
# 1998-03-17 00:00:00
# mse anomaly  min, max =  -47954.594 33152.938 joule / kilogram
# u anomaly  min, max =  -30.866804 82.484055 meter / second
# v anomaly  min, max =  -56.361248 62.367558 meter / second
# ubar_hp_dx_vint  min, max =  -2649.499724901575 2054.2456269207396 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1775.6350118997552 1669.3449152296007 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4093.084352959568 6821.546623419081 watt / meter ** 2
# w  min, max =  -10.685495 2.5220037 pascal / second
# wp  min, max =  -10.669867 2.5254164 pascal / second
# wp_hp_dp_vint  min, max =  -3209.883072962126 12059.33632476355 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1060.0218124049943 792.6324405130249 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -14998.46007462109 3098.1464991044177 watt / meter ** 2
# 1998-03-18 00:00:00
# mse anomaly  min, max =  -49147.062 35027.312 joule / kilogram
# u anomaly  min, max =  -29.701855 76.97093 meter / second
# v anomaly  min, max =  -51.7633 51.45469 meter / second
# ubar_hp_dx_vint  min, max =  -2668.128454942317 3894.3024935589688 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2003.0661236575643 1803.9673810610018 watt / meter ** 2
# up_hp_dx_vint  min, max =  -6781.616555566913 7085.17627776989 watt / meter ** 2
# w  min, max =  -8.7998495 3.027184 pascal / second
# wp  min, max =  -8.826053 3.029424 pascal / second
# wp_hp_dp_vint  min, max =  -3867.8533924505214 11630.284041866427 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1092.0642085275924 827.8796749759654 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -13003.231153043826 4563.094164915531 watt / meter ** 2
# 1998-03-19 00:00:00
# mse anomaly  min, max =  -54279.344 32922.97 joule / kilogram
# u anomaly  min, max =  -29.584599 80.16253 meter / second
# v anomaly  min, max =  -67.42592 48.934235 meter / second
# ubar_hp_dx_vint  min, max =  -3736.1687813107983 3005.3582449213745 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1322.6865691197324 1630.769729232378 watt / meter ** 2
# up_hp_dx_vint  min, max =  -2924.2898728472924 6596.590498851939 watt / meter ** 2
# w  min, max =  -7.2245955 2.3321145 pascal / second
# wp  min, max =  -7.2465153 2.3245988 pascal / second
# wp_hp_dp_vint  min, max =  -3323.89875025356 11632.866649747957 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1000.2138287798678 830.7915570792682 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -13646.906873289101 2940.16622162328 watt / meter ** 2
# 1998-03-20 00:00:00
# mse anomaly  min, max =  -56054.97 31729.719 joule / kilogram
# u anomaly  min, max =  -28.911198 104.82314 meter / second
# v anomaly  min, max =  -65.7483 47.64241 meter / second
# ubar_hp_dx_vint  min, max =  -4069.876611363192 3592.5729785414655 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1753.607782624448 1397.6715927601538 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3849.392073619975 6484.838820059511 watt / meter ** 2
# w  min, max =  -9.316928 2.5884838 pascal / second
# wp  min, max =  -9.338613 2.5934322 pascal / second
# wp_hp_dp_vint  min, max =  -2620.993885449626 6688.36987494679 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1179.880397228587 825.3202914902294 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -10071.915960700175 2956.735243919713 watt / meter ** 2
# 1998-03-21 00:00:00
# mse anomaly  min, max =  -52732.25 31334.375 joule / kilogram
# u anomaly  min, max =  -30.368832 94.944565 meter / second
# v anomaly  min, max =  -54.97433 48.72371 meter / second
# ubar_hp_dx_vint  min, max =  -4709.499020509187 2846.200315694861 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1378.1106062528772 1240.5057284661934 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3594.3563717338234 7919.469186957575 watt / meter ** 2
# w  min, max =  -9.29016 2.778722 pascal / second
# wp  min, max =  -9.293168 2.7448437 pascal / second
# wp_hp_dp_vint  min, max =  -2147.2554913844065 10948.097418440288 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1187.555631649375 1004.8336975578893 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -13192.013859332337 2878.2889570005973 watt / meter ** 2
# 1998-03-22 00:00:00
# mse anomaly  min, max =  -53218.5 32205.062 joule / kilogram
# u anomaly  min, max =  -30.021843 86.16347 meter / second
# v anomaly  min, max =  -64.76295 52.911526 meter / second
# ubar_hp_dx_vint  min, max =  -3562.0543804904664 2306.1279098676605 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1463.8915843771813 1589.4822228091068 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3628.89337031505 8371.69179643409 watt / meter ** 2
# w  min, max =  -11.618153 2.4565935 pascal / second
# wp  min, max =  -11.617699 2.4321356 pascal / second
# wp_hp_dp_vint  min, max =  -3420.777500085437 9310.744578276775 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1158.1843806082238 1037.0525615179984 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -11540.746735143059 2931.6487879681627 watt / meter ** 2
# 1998-03-23 00:00:00
# mse anomaly  min, max =  -58221.53 30824.938 joule / kilogram
# u anomaly  min, max =  -32.408073 77.21834 meter / second
# v anomaly  min, max =  -68.30946 80.127846 meter / second
# ubar_hp_dx_vint  min, max =  -3209.3122159099003 2517.075994485456 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1497.898494429624 1309.0426658371755 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4992.268644021322 7101.800638933654 watt / meter ** 2
# w  min, max =  -9.70012 2.4852767 pascal / second
# wp  min, max =  -9.727147 2.5428474 pascal / second
# wp_hp_dp_vint  min, max =  -4971.801116403019 12547.442353785667 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -927.6661501735726 966.886371387241 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -15425.36968096792 4794.060832284464 watt / meter ** 2
# 1998-03-24 00:00:00
# mse anomaly  min, max =  -47939.844 31711.156 joule / kilogram
# u anomaly  min, max =  -41.298504 77.37525 meter / second
# v anomaly  min, max =  -69.88638 77.90495 meter / second
# ubar_hp_dx_vint  min, max =  -2403.684046129131 2413.4941944234242 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1510.7739906347324 1383.635883795773 watt / meter ** 2
# up_hp_dx_vint  min, max =  -2850.154294970391 6055.381241498124 watt / meter ** 2
# w  min, max =  -11.04701 3.2271848 pascal / second
# wp  min, max =  -11.073145 3.2078235 pascal / second
# wp_hp_dp_vint  min, max =  -4207.876647164092 16347.248478870582 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -967.0923007143844 840.0835950154064 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -17756.417397060075 4917.805982419837 watt / meter ** 2
# 1998-03-25 00:00:00
# mse anomaly  min, max =  -48960.906 31841.969 joule / kilogram
# u anomaly  min, max =  -46.18714 81.04963 meter / second
# v anomaly  min, max =  -73.617096 73.97967 meter / second
# ubar_hp_dx_vint  min, max =  -2816.0500240294996 3315.175404217459 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1650.4854849718402 1095.9028004154804 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3811.188566054895 6922.523574045774 watt / meter ** 2
# w  min, max =  -11.335959 3.0165973 pascal / second
# wp  min, max =  -11.365144 3.1057816 pascal / second
# wp_hp_dp_vint  min, max =  -4408.183533236384 12993.577870845038 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1082.6260508262953 789.0477967454711 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -14959.355560280916 3599.7323768341007 watt / meter ** 2
# 1998-03-26 00:00:00
# mse anomaly  min, max =  -49835.5 32041.75 joule / kilogram
# u anomaly  min, max =  -45.02247 81.84818 meter / second
# v anomaly  min, max =  -68.30657 70.00373 meter / second
# ubar_hp_dx_vint  min, max =  -2353.8359315978696 2203.068980091069 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1534.4197879812991 2050.84750131358 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3927.95135107727 7294.248799956124 watt / meter ** 2
# w  min, max =  -7.7910085 3.805194 pascal / second
# wp  min, max =  -7.8182006 3.924752 pascal / second
# wp_hp_dp_vint  min, max =  -3770.466460490992 9435.844033639252 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1340.4184163670814 858.9017049557317 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -11107.287280591187 3395.1553404571005 watt / meter ** 2
# 1998-03-27 00:00:00
# mse anomaly  min, max =  -44088.406 31082.906 joule / kilogram
# u anomaly  min, max =  -30.91897 78.562744 meter / second
# v anomaly  min, max =  -71.96805 68.35768 meter / second
# ubar_hp_dx_vint  min, max =  -2769.746760457662 2326.073908962093 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1229.169311253971 1631.2388313212105 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4167.478560772805 10041.725193095903 watt / meter ** 2
# w  min, max =  -10.337911 5.2601004 pascal / second
# wp  min, max =  -10.3633375 5.200785 pascal / second
# wp_hp_dp_vint  min, max =  -4751.980814641151 17053.841781241113 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1424.4917513320695 737.0802115700442 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -21150.39658230141 3311.783419910514 watt / meter ** 2
# 1998-03-28 00:00:00
# mse anomaly  min, max =  -46522.562 32336.5 joule / kilogram
# u anomaly  min, max =  -36.869057 81.27756 meter / second
# v anomaly  min, max =  -61.967762 66.086914 meter / second
# ubar_hp_dx_vint  min, max =  -2184.5264318571617 1956.8976766148032 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1455.9928368883377 2810.1859956147327 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3269.8049480322743 6886.098018397778 watt / meter ** 2
# w  min, max =  -6.4050193 3.207076 pascal / second
# wp  min, max =  -6.4472103 3.2254107 pascal / second
# wp_hp_dp_vint  min, max =  -3420.0283642706786 7261.001127098315 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1691.6734873437963 761.8520799170749 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -7744.233027595064 3180.215724998251 watt / meter ** 2
# 1998-03-29 00:00:00
# mse anomaly  min, max =  -47803.438 33374.22 joule / kilogram
# u anomaly  min, max =  -30.32503 80.74709 meter / second
# v anomaly  min, max =  -70.810234 64.241806 meter / second
# ubar_hp_dx_vint  min, max =  -2865.891481912482 2716.905550603715 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -2182.4546026427206 2941.102436002484 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3981.689238014521 9526.896574409653 watt / meter ** 2
# w  min, max =  -8.060211 3.8234057 pascal / second
# wp  min, max =  -8.088149 3.8432703 pascal / second
# wp_hp_dp_vint  min, max =  -4638.032687093084 10263.051076960459 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1654.1874912619562 664.413200006155 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -12683.633412361374 3311.6369702301477 watt / meter ** 2
# 1998-03-30 00:00:00
# mse anomaly  min, max =  -49602.0 36636.125 joule / kilogram
# u anomaly  min, max =  -38.835583 76.89351 meter / second
# v anomaly  min, max =  -65.21346 63.8725 meter / second
# ubar_hp_dx_vint  min, max =  -2916.591723103973 3662.107887824161 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1310.7094486161561 2130.070213706562 watt / meter ** 2
# up_hp_dx_vint  min, max =  -4154.280633811418 8994.918659543207 watt / meter ** 2
# w  min, max =  -6.2414637 2.9587648 pascal / second
# wp  min, max =  -6.26794 2.956424 pascal / second
# wp_hp_dp_vint  min, max =  -4258.329780605823 7423.045668243202 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1565.9136088008786 1018.4189266207765 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -8905.240403093265 3873.2556904644634 watt / meter ** 2
# 1998-03-31 00:00:00
# mse anomaly  min, max =  -52265.875 36864.875 joule / kilogram
# u anomaly  min, max =  -33.12883 69.482635 meter / second
# v anomaly  min, max =  -58.42652 61.48159 meter / second
# ubar_hp_dx_vint  min, max =  -3612.301336981473 2120.0856333046686 watt / meter ** 2
# up_hbar_dx_vint  min, max =  -1663.520942245829 1105.734932026822 watt / meter ** 2
# up_hp_dx_vint  min, max =  -3508.307318956967 8749.088879096722 watt / meter ** 2
# w  min, max =  -8.020995 2.8606954 pascal / second
# wp  min, max =  -8.047767 2.881772 pascal / second
# wp_hp_dp_vint  min, max =  -7292.820473636288 12103.164632415455 watt / meter ** 2
# wbar_hp_dp_vint  min, max =  -1527.8856615099155 927.5099627975718 watt / meter ** 2
# wp_hbar_dp_vint  min, max =  -13913.043989799198 4519.610949580515 watt / meter ** 2
